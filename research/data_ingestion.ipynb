# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\Ankit\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\Ankit\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\Ankit\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\Ankit\\AppData\\Local\\Programs\\Python\\Python311', 'd:\\Python\\Industry level\\Machine learning\\CreditRiskManagement\\myvenv', '', 'd:\\Python\\Industry level\\Machine learning\\CreditRiskManagement\\myvenv\\Lib\\site-packages']

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_url: str
    local_data_file: Path
    unzip_dir: Path

# %%
import os
# %pwd
# Out:
# 'd:\\Python\\Industry level\\Machine learning\\CreditRiskManagement\\research'

# %%
os.chdir('D:\Python\Industry level\Machine learning\CreditRiskManagement')
# %pwd
# Out:
# 'D:\\Python\\Industry level\\Machine learning\\CreditRiskManagement'

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml,create_directories
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 2
#       1 from mlProject.constants import *
# ----> 2 from mlProject.utils.common import read_yaml,create_directories
#
# ImportError: cannot import name 'read_yaml' from 'mlProject.utils.common' (D:\Python\Industry level\Machine learning\CreditRiskManagement\mlProject\utils\common.py)
